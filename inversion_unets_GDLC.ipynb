# %%
# Mount Google Drive
# This is just for Google Colab
from google.colab import drive
drive.mount('/content/drive')

# Set the directory at MyDrive
# This is just when running on Google colab
import os
os.chdir('/content/drive/MyDrive/')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
from sklearn.model_selection import train_test_split
import copy
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Cropping2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from scipy import interpolate
from scipy.interpolate import NearestNDInterpolator

# Load the training data (BScans)
# np.shape(train) = (number of samples, 230, 230)
# The Bscans are already normalised
train = np.load('Bscan_Kaggle.npy')

# Load the labels (permittivity ground truth)
# np.shape(labels) = (number of samples, 224, 224)
labels = np.load('Labels_Kaggle.npy')


for i, c in enumerate(train):
    # Go through my training data i.e. BScans
    # Normalise them from -1 to 1
    train[i] = c/np.max(np.abs(c))
    # Normalise the labels from -0.5 to 0.5
    labels[i] = labels[i]/10 - 0.5

    # plt.imshow(labels[i])
    # plt.colorbar()
    # plt.show()

# %%
from tensorflow.keras.layers import ZeroPadding2D, BatchNormalization
from tensorflow.keras.initializers import he_normal



def unet_model(input_size=(230, 230, 1)):
    # This is a vanilla typical U-net that takes an image as input with 230x230 dimensions and gives another image as an output with 224x224 dimensions
    # The hyperparameters are not tuned.


    inputs = Input(input_size)

    # Size of the kernels
    ra=4
    # Encoding path
    c1 = Conv2D(16, (ra, ra), activation='relu', padding='same', kernel_initializer=he_normal())(inputs)
    # c1 = BatchNormalization()(c1)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (ra, ra), activation='relu', padding='same', kernel_initializer=he_normal())(c1)
    # c1 = BatchNormalization()(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(p1)
    # c2 = BatchNormalization()(c2)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(c2)
    # c2 = BatchNormalization()(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(p2)
    # c3 = BatchNormalization()(c3)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(c3)
    # c3 = BatchNormalization()(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(p3)
    # c4 = BatchNormalization()(c4)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(c4)
    # c4 = BatchNormalization()(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(p4)
    # c5 = BatchNormalization()(c5)

    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(c5)
    # c5 = BatchNormalization()(c5)

    # Decoding path
    u6 = UpSampling2D((2, 2))(c5)
    # c4 = Cropping2D(cropping=((1, 0), (1, 0)))(c4)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(u6)
    # c6 = BatchNormalization()(c6)

    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(c6)
    # c6 = BatchNormalization()(c6)

    u7 = UpSampling2D((2, 2))(c6)

    c3 = Cropping2D(cropping=((1, 0), (1, 0)))(c3)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(u7)
    # c7 = BatchNormalization()(c7)

    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(c7)
    # c7 = BatchNormalization()(c7)

    u8 = UpSampling2D((2, 2))(c7)
    c2 = Cropping2D(cropping=((2, 1), (2, 1)))(c2)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(u8)
    # c8 = BatchNormalization()(c8)

    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(c8)
    # c8 = BatchNormalization()(c8)

    u9 = UpSampling2D((2, 2))(c8)
    c1 = Cropping2D(cropping=((3, 3), (3, 3)))(c1)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(32, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(u9)
    # c9 = BatchNormalization()(c9)

    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (ra, ra), activation='relu', padding='same',kernel_initializer=he_normal())(c9)
    # c9 = BatchNormalization()(c9)

    outputs = Conv2D(1, (1, 1), activation='linear')(c9)
    # outputs = UpSampling2D((2, 2))(c10)


    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
# Divide the data in training and testing. We use 10% for testing purposes.
x_train, x_test, y_train, y_test = train_test_split(train[:,:,:], labels[:,:,:], test_size = 0.1)

# We increase the dimensions by 1 to be consisted with the tensorflow format
x_train = x_train[...,np.newaxis]
y_train = y_train[...,np.newaxis]
x_test = x_test[...,np.newaxis]
y_test = y_test[...,np.newaxis]

# The size of the Bscans i.e. the inputs of the U-net
input_size = (230, 230, 1)
# Initialise the unet
model = unet_model(input_size)

# You can play with the loss, instead of using a typucal mse or mae you can add e.g. a total variational constrain to force the model to be blocky
def custom_loss(y_true, y_pred):
    # Mean Absolute Error
    mae = tf.math.reduce_mean(tf.math.abs(y_true - y_pred))

    # Mean Absolute Differences
    # reg=tf.math.reduce_mean(tf.math.abs(y_pred[1:]-y_pred[:-1]))

    # return mae + reg*0.001

    return mae



# Generate 10 models to apply ensemble U-nets
for i in range(0,10):
    model = unet_model(input_size)
    # Compile the model
    model.compile(optimizer='adam', loss=custom_loss, metrics=['mae'])

    # You can play with this parameter. Usually learning rate of adam should decrease as the iterations increase
    model.optimizer.learning_rate = 5e-4

    # The model with the best performance in the validation set will be saved in best_model_2_1.hp5
    p1 = EarlyStopping(monitor="val_loss", mode= "min", verbose=1, patience=30)
    p2 = ModelCheckpoint('best_model_2_{}.hp5'.format(i), monitor="val_loss", mode="min", save_best_only=True )

    # Train the model with 5 batch size for 15 epochs
    history = model.fit(x_train, y_train, epochs=55, batch_size=5, validation_split=0.1, callbacks=[p1, p2])

    # Decrease the learning rate and train for another 10 epochs
    model.optimizer.learning_rate = 1e-4
    history = model.fit(x_train, y_train, epochs=30, batch_size=5, validation_split=0.1, callbacks=[p1, p2])

    # Decrease the learning rate and traing for another 10 epochs
    model.optimizer.learning_rate = 5e-5
    history = model.fit(x_train, y_train, epochs=30, batch_size=5, validation_split=0.1, callbacks=[p1, p2])
# Out:
# Epoch 1/55
#
# 713/713 [==============================] - 34s 29ms/step - loss: 0.1646 - mae: 0.1646 - val_loss: 0.1549 - val_mae: 0.1549
#
# Epoch 2/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1513 - mae: 0.1513 - val_loss: 0.1438 - val_mae: 0.1438
#
# Epoch 3/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1406 - mae: 0.1406 - val_loss: 0.1327 - val_mae: 0.1327
#
# Epoch 4/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1293 - mae: 0.1293 - val_loss: 0.1204 - val_mae: 0.1204
#
# Epoch 5/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1213 - mae: 0.1213 - val_loss: 0.1148 - val_mae: 0.1148
#
# Epoch 6/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1155 - mae: 0.1155 - val_loss: 0.1118 - val_mae: 0.1118
#
# Epoch 7/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.1113 - mae: 0.1113 - val_loss: 0.1118 - val_mae: 0.1118
#
# Epoch 8/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1074 - mae: 0.1074 - val_loss: 0.1063 - val_mae: 0.1063
#
# Epoch 9/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1047 - mae: 0.1047 - val_loss: 0.1045 - val_mae: 0.1045
#
# Epoch 10/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1021 - mae: 0.1021 - val_loss: 0.1024 - val_mae: 0.1024
#
# Epoch 11/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.1001 - mae: 0.1001 - val_loss: 0.1058 - val_mae: 0.1058
#
# Epoch 12/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0985 - mae: 0.0985 - val_loss: 0.1007 - val_mae: 0.1007
#
# Epoch 13/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0956 - mae: 0.0956 - val_loss: 0.1009 - val_mae: 0.1009
#
# Epoch 14/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0939 - mae: 0.0939 - val_loss: 0.1002 - val_mae: 0.1002
#
# Epoch 15/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0919 - mae: 0.0919 - val_loss: 0.0987 - val_mae: 0.0987
#
# Epoch 16/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0903 - mae: 0.0903 - val_loss: 0.0992 - val_mae: 0.0992
#
# Epoch 17/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0886 - mae: 0.0886 - val_loss: 0.0978 - val_mae: 0.0978
#
# Epoch 18/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0865 - mae: 0.0865 - val_loss: 0.0974 - val_mae: 0.0974
#
# Epoch 19/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0855 - mae: 0.0855 - val_loss: 0.0980 - val_mae: 0.0980
#
# Epoch 20/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0837 - mae: 0.0837 - val_loss: 0.0951 - val_mae: 0.0951
#
# Epoch 21/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0823 - mae: 0.0823 - val_loss: 0.0972 - val_mae: 0.0972
#
# Epoch 22/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0807 - mae: 0.0807 - val_loss: 0.0976 - val_mae: 0.0976
#
# Epoch 23/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0793 - mae: 0.0793 - val_loss: 0.0972 - val_mae: 0.0972
#
# Epoch 24/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0780 - mae: 0.0780 - val_loss: 0.0958 - val_mae: 0.0958
#
# Epoch 25/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0766 - mae: 0.0766 - val_loss: 0.0943 - val_mae: 0.0943
#
# Epoch 26/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0754 - mae: 0.0754 - val_loss: 0.0962 - val_mae: 0.0962
#
# Epoch 27/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0740 - mae: 0.0740 - val_loss: 0.0960 - val_mae: 0.0960
#
# Epoch 28/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0733 - mae: 0.0733 - val_loss: 0.0958 - val_mae: 0.0958
#
# Epoch 29/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0722 - mae: 0.0722 - val_loss: 0.0965 - val_mae: 0.0965
#
# Epoch 30/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0711 - mae: 0.0711 - val_loss: 0.0956 - val_mae: 0.0956
#
# Epoch 31/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0702 - mae: 0.0702 - val_loss: 0.0966 - val_mae: 0.0966
#
# Epoch 32/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0694 - mae: 0.0694 - val_loss: 0.0976 - val_mae: 0.0976
#
# Epoch 33/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0686 - mae: 0.0686 - val_loss: 0.0958 - val_mae: 0.0958
#
# Epoch 34/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0679 - mae: 0.0679 - val_loss: 0.0956 - val_mae: 0.0956
#
# Epoch 35/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0667 - mae: 0.0667 - val_loss: 0.0965 - val_mae: 0.0965
#
# Epoch 36/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0661 - mae: 0.0661 - val_loss: 0.0951 - val_mae: 0.0951
#
# Epoch 37/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0654 - mae: 0.0654 - val_loss: 0.0965 - val_mae: 0.0965
#
# Epoch 38/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0645 - mae: 0.0645 - val_loss: 0.0981 - val_mae: 0.0981
#
# Epoch 39/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0646 - mae: 0.0646 - val_loss: 0.0947 - val_mae: 0.0947
#
# Epoch 40/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0634 - mae: 0.0634 - val_loss: 0.0948 - val_mae: 0.0948
#
# Epoch 41/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0628 - mae: 0.0628 - val_loss: 0.0950 - val_mae: 0.0950
#
# Epoch 42/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0627 - mae: 0.0627 - val_loss: 0.0981 - val_mae: 0.0981
#
# Epoch 43/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0620 - mae: 0.0620 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 44/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0612 - mae: 0.0612 - val_loss: 0.0962 - val_mae: 0.0962
#
# Epoch 45/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0608 - mae: 0.0608 - val_loss: 0.0951 - val_mae: 0.0951
#
# Epoch 46/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0606 - mae: 0.0606 - val_loss: 0.0951 - val_mae: 0.0951
#
# Epoch 47/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0598 - mae: 0.0598 - val_loss: 0.0957 - val_mae: 0.0957
#
# Epoch 48/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0593 - mae: 0.0593 - val_loss: 0.0950 - val_mae: 0.0950
#
# Epoch 49/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0593 - mae: 0.0593 - val_loss: 0.0936 - val_mae: 0.0936
#
# Epoch 50/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0587 - mae: 0.0587 - val_loss: 0.0944 - val_mae: 0.0944
#
# Epoch 51/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0583 - mae: 0.0583 - val_loss: 0.0965 - val_mae: 0.0965
#
# Epoch 52/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0579 - mae: 0.0579 - val_loss: 0.0944 - val_mae: 0.0944
#
# Epoch 53/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0575 - mae: 0.0575 - val_loss: 0.0958 - val_mae: 0.0958
#
# Epoch 54/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0570 - mae: 0.0570 - val_loss: 0.0945 - val_mae: 0.0945
#
# Epoch 55/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0567 - mae: 0.0567 - val_loss: 0.0948 - val_mae: 0.0948
#
# Epoch 1/30
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0523 - mae: 0.0523 - val_loss: 0.0935 - val_mae: 0.0935
#
# Epoch 2/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0508 - mae: 0.0508 - val_loss: 0.0940 - val_mae: 0.0940
#
# Epoch 3/30
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0501 - mae: 0.0501 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 4/30
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0498 - mae: 0.0498 - val_loss: 0.0927 - val_mae: 0.0927
#
# Epoch 5/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0495 - mae: 0.0495 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 6/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0491 - mae: 0.0491 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 7/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0487 - mae: 0.0487 - val_loss: 0.0934 - val_mae: 0.0934
#
# Epoch 8/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0485 - mae: 0.0485 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 9/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0483 - mae: 0.0483 - val_loss: 0.0933 - val_mae: 0.0933
#
# Epoch 10/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0481 - mae: 0.0481 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 11/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0479 - mae: 0.0479 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 12/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0477 - mae: 0.0477 - val_loss: 0.0934 - val_mae: 0.0934
#
# Epoch 13/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0475 - mae: 0.0475 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 14/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0473 - mae: 0.0473 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 15/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0472 - mae: 0.0472 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 16/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0470 - mae: 0.0470 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 17/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0469 - mae: 0.0469 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 18/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0468 - mae: 0.0468 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 19/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0466 - mae: 0.0466 - val_loss: 0.0934 - val_mae: 0.0934
#
# Epoch 20/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0466 - mae: 0.0466 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 21/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0464 - mae: 0.0464 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 22/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0463 - mae: 0.0463 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 23/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0462 - mae: 0.0462 - val_loss: 0.0934 - val_mae: 0.0934
#
# Epoch 24/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0460 - mae: 0.0460 - val_loss: 0.0939 - val_mae: 0.0939
#
# Epoch 25/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0459 - mae: 0.0459 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 26/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0458 - mae: 0.0458 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 27/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0457 - mae: 0.0457 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 28/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0456 - mae: 0.0456 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 29/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0454 - mae: 0.0454 - val_loss: 0.0934 - val_mae: 0.0934
#
# Epoch 30/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0453 - mae: 0.0453 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 1/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0448 - mae: 0.0448 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 2/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0446 - mae: 0.0446 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 3/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0445 - mae: 0.0445 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 4/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0444 - mae: 0.0444 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 5/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0444 - mae: 0.0444 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 6/30
#
# 713/713 [==============================] - 15s 20ms/step - loss: 0.0442 - mae: 0.0442 - val_loss: 0.0926 - val_mae: 0.0926
#
# Epoch 7/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0442 - mae: 0.0442 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 8/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0442 - mae: 0.0442 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 9/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0441 - mae: 0.0441 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 10/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0440 - mae: 0.0440 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 11/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0439 - mae: 0.0439 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 12/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0438 - mae: 0.0438 - val_loss: 0.0933 - val_mae: 0.0933
#
# Epoch 13/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0437 - mae: 0.0437 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 14/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0438 - mae: 0.0438 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 15/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0436 - mae: 0.0436 - val_loss: 0.0933 - val_mae: 0.0933
#
# Epoch 16/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0436 - mae: 0.0436 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 17/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0435 - mae: 0.0435 - val_loss: 0.0933 - val_mae: 0.0933
#
# Epoch 18/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0436 - mae: 0.0436 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 19/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0435 - mae: 0.0435 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 20/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0434 - mae: 0.0434 - val_loss: 0.0927 - val_mae: 0.0927
#
# Epoch 21/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0434 - mae: 0.0434 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 22/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0433 - mae: 0.0433 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 23/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0433 - mae: 0.0433 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 24/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0432 - mae: 0.0432 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 25/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0432 - mae: 0.0432 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 26/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0432 - mae: 0.0432 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 27/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0431 - mae: 0.0431 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 28/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0430 - mae: 0.0430 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 29/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0429 - mae: 0.0429 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 30/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0429 - mae: 0.0429 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 1/55
#
# 713/713 [==============================] - 23s 25ms/step - loss: 0.1613 - mae: 0.1613 - val_loss: 0.1595 - val_mae: 0.1595
#
# Epoch 2/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1548 - mae: 0.1548 - val_loss: 0.1470 - val_mae: 0.1470
#
# Epoch 3/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1473 - mae: 0.1473 - val_loss: 0.1376 - val_mae: 0.1376
#
# Epoch 4/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1326 - mae: 0.1326 - val_loss: 0.1267 - val_mae: 0.1267
#
# Epoch 5/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1226 - mae: 0.1226 - val_loss: 0.1172 - val_mae: 0.1172
#
# Epoch 6/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1159 - mae: 0.1159 - val_loss: 0.1132 - val_mae: 0.1132
#
# Epoch 7/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1117 - mae: 0.1117 - val_loss: 0.1078 - val_mae: 0.1078
#
# Epoch 8/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.1089 - mae: 0.1089 - val_loss: 0.1086 - val_mae: 0.1086
#
# Epoch 9/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.1053 - mae: 0.1053 - val_loss: 0.1081 - val_mae: 0.1081
#
# Epoch 10/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1034 - mae: 0.1034 - val_loss: 0.1067 - val_mae: 0.1067
#
# Epoch 11/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1009 - mae: 0.1009 - val_loss: 0.1036 - val_mae: 0.1036
#
# Epoch 12/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0992 - mae: 0.0992 - val_loss: 0.1021 - val_mae: 0.1021
#
# Epoch 13/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0976 - mae: 0.0976 - val_loss: 0.1012 - val_mae: 0.1012
#
# Epoch 14/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0957 - mae: 0.0957 - val_loss: 0.0996 - val_mae: 0.0996
#
# Epoch 15/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0937 - mae: 0.0937 - val_loss: 0.0998 - val_mae: 0.0998
#
# Epoch 16/55
#
# 713/713 [==============================] - 15s 20ms/step - loss: 0.0920 - mae: 0.0920 - val_loss: 0.0980 - val_mae: 0.0980
#
# Epoch 17/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0907 - mae: 0.0907 - val_loss: 0.0984 - val_mae: 0.0984
#
# Epoch 18/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0888 - mae: 0.0888 - val_loss: 0.1005 - val_mae: 0.1005
#
# Epoch 19/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0878 - mae: 0.0878 - val_loss: 0.0991 - val_mae: 0.0991
#
# Epoch 20/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0862 - mae: 0.0862 - val_loss: 0.0992 - val_mae: 0.0992
#
# Epoch 21/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0847 - mae: 0.0847 - val_loss: 0.0987 - val_mae: 0.0987
#
# Epoch 22/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0838 - mae: 0.0838 - val_loss: 0.0987 - val_mae: 0.0987
#
# Epoch 23/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0823 - mae: 0.0823 - val_loss: 0.0986 - val_mae: 0.0986
#
# Epoch 24/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0811 - mae: 0.0811 - val_loss: 0.0966 - val_mae: 0.0966
#
# Epoch 25/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0795 - mae: 0.0795 - val_loss: 0.0979 - val_mae: 0.0979
#
# Epoch 26/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0788 - mae: 0.0788 - val_loss: 0.0968 - val_mae: 0.0968
#
# Epoch 27/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0778 - mae: 0.0778 - val_loss: 0.0983 - val_mae: 0.0983
#
# Epoch 28/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0765 - mae: 0.0765 - val_loss: 0.0965 - val_mae: 0.0965
#
# Epoch 29/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0758 - mae: 0.0758 - val_loss: 0.0985 - val_mae: 0.0985
#
# Epoch 30/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0745 - mae: 0.0745 - val_loss: 0.0963 - val_mae: 0.0963
#
# Epoch 31/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0733 - mae: 0.0733 - val_loss: 0.0965 - val_mae: 0.0965
#
# Epoch 32/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0729 - mae: 0.0729 - val_loss: 0.0973 - val_mae: 0.0973
#
# Epoch 33/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0724 - mae: 0.0724 - val_loss: 0.0967 - val_mae: 0.0967
#
# Epoch 34/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0710 - mae: 0.0710 - val_loss: 0.0948 - val_mae: 0.0948
#
# Epoch 35/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0710 - mae: 0.0710 - val_loss: 0.0972 - val_mae: 0.0972
#
# Epoch 36/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0697 - mae: 0.0697 - val_loss: 0.0954 - val_mae: 0.0954
#
# Epoch 37/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0690 - mae: 0.0690 - val_loss: 0.0952 - val_mae: 0.0952
#
# Epoch 38/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0681 - mae: 0.0681 - val_loss: 0.0966 - val_mae: 0.0966
#
# Epoch 39/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0680 - mae: 0.0680 - val_loss: 0.0976 - val_mae: 0.0976
#
# Epoch 40/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0672 - mae: 0.0672 - val_loss: 0.0951 - val_mae: 0.0951
#
# Epoch 41/55
#
# 713/713 [==============================] - 15s 20ms/step - loss: 0.0665 - mae: 0.0665 - val_loss: 0.0948 - val_mae: 0.0948
#
# Epoch 42/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0661 - mae: 0.0661 - val_loss: 0.0961 - val_mae: 0.0961
#
# Epoch 43/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0950 - val_mae: 0.0950
#
# Epoch 44/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 45/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0643 - mae: 0.0643 - val_loss: 0.0944 - val_mae: 0.0944
#
# Epoch 46/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0635 - mae: 0.0635 - val_loss: 0.0952 - val_mae: 0.0952
#
# Epoch 47/55
#
# 713/713 [==============================] - 15s 20ms/step - loss: 0.0630 - mae: 0.0630 - val_loss: 0.0943 - val_mae: 0.0943
#
# Epoch 48/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0626 - mae: 0.0626 - val_loss: 0.0949 - val_mae: 0.0949
#
# Epoch 49/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0626 - mae: 0.0626 - val_loss: 0.0944 - val_mae: 0.0944
#
# Epoch 50/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0618 - mae: 0.0618 - val_loss: 0.0948 - val_mae: 0.0948
#
# Epoch 51/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0618 - mae: 0.0618 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 52/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0613 - mae: 0.0613 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 53/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0609 - mae: 0.0609 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 54/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0599 - mae: 0.0599 - val_loss: 0.0944 - val_mae: 0.0944
#
# Epoch 55/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0600 - mae: 0.0600 - val_loss: 0.0960 - val_mae: 0.0960
#
# Epoch 1/30
#
# 713/713 [==============================] - 15s 22ms/step - loss: 0.0553 - mae: 0.0553 - val_loss: 0.0933 - val_mae: 0.0933
#
# Epoch 2/30
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0538 - mae: 0.0538 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 3/30
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0532 - mae: 0.0532 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 4/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0528 - mae: 0.0528 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 5/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0523 - mae: 0.0523 - val_loss: 0.0934 - val_mae: 0.0934
#
# Epoch 6/30
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0521 - mae: 0.0521 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 7/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0517 - mae: 0.0517 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 8/30
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0516 - mae: 0.0516 - val_loss: 0.0926 - val_mae: 0.0926
#
# Epoch 9/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0512 - mae: 0.0512 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 10/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0512 - mae: 0.0512 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 11/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0508 - mae: 0.0508 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 12/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0507 - mae: 0.0507 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 13/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0506 - mae: 0.0506 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 14/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0502 - mae: 0.0502 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 15/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0501 - mae: 0.0501 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 16/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0499 - mae: 0.0499 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 17/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0497 - mae: 0.0497 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 18/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0497 - mae: 0.0497 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 19/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0494 - mae: 0.0494 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 20/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0494 - mae: 0.0494 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 21/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0493 - mae: 0.0493 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 22/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0492 - mae: 0.0492 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 23/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0491 - mae: 0.0491 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 24/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0488 - mae: 0.0488 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 25/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0488 - mae: 0.0488 - val_loss: 0.0927 - val_mae: 0.0927
#
# Epoch 26/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0486 - mae: 0.0486 - val_loss: 0.0927 - val_mae: 0.0927
#
# Epoch 27/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0484 - mae: 0.0484 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 28/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0483 - mae: 0.0483 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 29/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0482 - mae: 0.0482 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 30/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0482 - mae: 0.0482 - val_loss: 0.0934 - val_mae: 0.0934
#
# Epoch 1/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0475 - mae: 0.0475 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 2/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0472 - mae: 0.0472 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 3/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0472 - mae: 0.0472 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 4/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0471 - mae: 0.0471 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 5/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0470 - mae: 0.0470 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 6/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0471 - mae: 0.0471 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 7/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0469 - mae: 0.0469 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 8/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0467 - mae: 0.0467 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 9/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0467 - mae: 0.0467 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 10/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0467 - mae: 0.0467 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 11/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0467 - mae: 0.0467 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 12/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0465 - mae: 0.0465 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 13/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0466 - mae: 0.0466 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 14/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0464 - mae: 0.0464 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 15/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0464 - mae: 0.0464 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 16/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0463 - mae: 0.0463 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 17/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0463 - mae: 0.0463 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 18/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0462 - mae: 0.0462 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 19/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0461 - mae: 0.0461 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 20/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0460 - mae: 0.0460 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 21/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0460 - mae: 0.0460 - val_loss: 0.0927 - val_mae: 0.0927
#
# Epoch 22/30
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0460 - mae: 0.0460 - val_loss: 0.0925 - val_mae: 0.0925
#
# Epoch 23/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0458 - mae: 0.0458 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 24/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0458 - mae: 0.0458 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 25/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0458 - mae: 0.0458 - val_loss: 0.0931 - val_mae: 0.0931
#
# Epoch 26/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0457 - mae: 0.0457 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 27/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0457 - mae: 0.0457 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 28/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0456 - mae: 0.0456 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 29/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0455 - mae: 0.0455 - val_loss: 0.0929 - val_mae: 0.0929
#
# Epoch 30/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0455 - mae: 0.0455 - val_loss: 0.0928 - val_mae: 0.0928
#
# Epoch 1/55
#
# 713/713 [==============================] - 23s 25ms/step - loss: 0.1611 - mae: 0.1611 - val_loss: 0.1579 - val_mae: 0.1579
#
# Epoch 2/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1594 - mae: 0.1594 - val_loss: 0.1572 - val_mae: 0.1572
#
# Epoch 3/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1568 - mae: 0.1568 - val_loss: 0.1506 - val_mae: 0.1506
#
# Epoch 4/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1487 - mae: 0.1487 - val_loss: 0.1409 - val_mae: 0.1409
#
# Epoch 5/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1389 - mae: 0.1389 - val_loss: 0.1298 - val_mae: 0.1298
#
# Epoch 6/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1297 - mae: 0.1297 - val_loss: 0.1219 - val_mae: 0.1219
#
# Epoch 7/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1226 - mae: 0.1226 - val_loss: 0.1166 - val_mae: 0.1166
#
# Epoch 8/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1158 - mae: 0.1158 - val_loss: 0.1154 - val_mae: 0.1154
#
# Epoch 9/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1111 - mae: 0.1111 - val_loss: 0.1088 - val_mae: 0.1088
#
# Epoch 10/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.1077 - mae: 0.1077 - val_loss: 0.1089 - val_mae: 0.1089
#
# Epoch 11/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1049 - mae: 0.1049 - val_loss: 0.1077 - val_mae: 0.1077
#
# Epoch 12/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1024 - mae: 0.1024 - val_loss: 0.1038 - val_mae: 0.1038
#
# Epoch 13/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0999 - mae: 0.0999 - val_loss: 0.1039 - val_mae: 0.1039
#
# Epoch 14/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0983 - mae: 0.0983 - val_loss: 0.1034 - val_mae: 0.1034
#
# Epoch 15/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0961 - mae: 0.0961 - val_loss: 0.1021 - val_mae: 0.1021
#
# Epoch 16/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0943 - mae: 0.0943 - val_loss: 0.0987 - val_mae: 0.0987
#
# Epoch 17/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0924 - mae: 0.0924 - val_loss: 0.0996 - val_mae: 0.0996
#
# Epoch 18/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0907 - mae: 0.0907 - val_loss: 0.1013 - val_mae: 0.1013
#
# Epoch 19/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0892 - mae: 0.0892 - val_loss: 0.1000 - val_mae: 0.1000
#
# Epoch 20/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0874 - mae: 0.0874 - val_loss: 0.0972 - val_mae: 0.0972
#
# Epoch 21/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0856 - mae: 0.0856 - val_loss: 0.0971 - val_mae: 0.0971
#
# Epoch 22/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0843 - mae: 0.0843 - val_loss: 0.0979 - val_mae: 0.0979
#
# Epoch 23/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0822 - mae: 0.0822 - val_loss: 0.0986 - val_mae: 0.0986
#
# Epoch 24/55
#
# 713/713 [==============================] - 15s 20ms/step - loss: 0.0821 - mae: 0.0821 - val_loss: 0.0966 - val_mae: 0.0966
#
# Epoch 25/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0797 - mae: 0.0797 - val_loss: 0.0990 - val_mae: 0.0990
#
# Epoch 26/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0788 - mae: 0.0788 - val_loss: 0.0963 - val_mae: 0.0963
#
# Epoch 27/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0779 - mae: 0.0779 - val_loss: 0.0971 - val_mae: 0.0971
#
# Epoch 28/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0767 - mae: 0.0767 - val_loss: 0.0965 - val_mae: 0.0965
#
# Epoch 29/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0760 - mae: 0.0760 - val_loss: 0.0976 - val_mae: 0.0976
#
# Epoch 30/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0747 - mae: 0.0747 - val_loss: 0.0967 - val_mae: 0.0967
#
# Epoch 31/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0733 - mae: 0.0733 - val_loss: 0.0958 - val_mae: 0.0958
#
# Epoch 32/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0728 - mae: 0.0728 - val_loss: 0.0964 - val_mae: 0.0964
#
# Epoch 33/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0719 - mae: 0.0719 - val_loss: 0.0965 - val_mae: 0.0965
#
# Epoch 34/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0711 - mae: 0.0711 - val_loss: 0.0957 - val_mae: 0.0957
#
# Epoch 35/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0701 - mae: 0.0701 - val_loss: 0.0960 - val_mae: 0.0960
#
# Epoch 36/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0693 - mae: 0.0693 - val_loss: 0.0969 - val_mae: 0.0969
#
# Epoch 37/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0684 - mae: 0.0684 - val_loss: 0.0959 - val_mae: 0.0959
#
# Epoch 38/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0681 - mae: 0.0681 - val_loss: 0.0967 - val_mae: 0.0967
#
# Epoch 39/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0669 - mae: 0.0669 - val_loss: 0.0963 - val_mae: 0.0963
#
# Epoch 40/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0664 - mae: 0.0664 - val_loss: 0.0956 - val_mae: 0.0956
#
# Epoch 41/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0657 - mae: 0.0657 - val_loss: 0.0963 - val_mae: 0.0963
#
# Epoch 42/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0651 - mae: 0.0651 - val_loss: 0.0963 - val_mae: 0.0963
#
# Epoch 43/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0647 - mae: 0.0647 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 44/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0638 - mae: 0.0638 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 45/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0637 - mae: 0.0637 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 46/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0631 - mae: 0.0631 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 47/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0624 - mae: 0.0624 - val_loss: 0.0968 - val_mae: 0.0968
#
# Epoch 48/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0621 - mae: 0.0621 - val_loss: 0.0968 - val_mae: 0.0968
#
# Epoch 49/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0613 - mae: 0.0613 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 50/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0610 - mae: 0.0610 - val_loss: 0.0973 - val_mae: 0.0973
#
# Epoch 51/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0608 - mae: 0.0608 - val_loss: 0.0964 - val_mae: 0.0964
#
# Epoch 52/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0602 - mae: 0.0602 - val_loss: 0.0952 - val_mae: 0.0952
#
# Epoch 53/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0596 - mae: 0.0596 - val_loss: 0.0957 - val_mae: 0.0957
#
# Epoch 54/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0593 - mae: 0.0593 - val_loss: 0.0950 - val_mae: 0.0950
#
# Epoch 55/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0590 - mae: 0.0590 - val_loss: 0.0952 - val_mae: 0.0952
#
# Epoch 1/30
#
# 713/713 [==============================] - 15s 22ms/step - loss: 0.0544 - mae: 0.0544 - val_loss: 0.0936 - val_mae: 0.0936
#
# Epoch 2/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0529 - mae: 0.0529 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 3/30
#
# 713/713 [==============================] - 15s 20ms/step - loss: 0.0523 - mae: 0.0523 - val_loss: 0.0933 - val_mae: 0.0933
#
# Epoch 4/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0520 - mae: 0.0520 - val_loss: 0.0943 - val_mae: 0.0943
#
# Epoch 5/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0516 - mae: 0.0516 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 6/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0512 - mae: 0.0512 - val_loss: 0.0936 - val_mae: 0.0936
#
# Epoch 7/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0509 - mae: 0.0509 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 8/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0507 - mae: 0.0507 - val_loss: 0.0936 - val_mae: 0.0936
#
# Epoch 9/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0504 - mae: 0.0504 - val_loss: 0.0940 - val_mae: 0.0940
#
# Epoch 10/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0503 - mae: 0.0503 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 11/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0501 - mae: 0.0501 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 12/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0498 - mae: 0.0498 - val_loss: 0.0939 - val_mae: 0.0939
#
# Epoch 13/30
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0497 - mae: 0.0497 - val_loss: 0.0932 - val_mae: 0.0932
#
# Epoch 14/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0495 - mae: 0.0495 - val_loss: 0.0936 - val_mae: 0.0936
#
# Epoch 15/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0493 - mae: 0.0493 - val_loss: 0.0935 - val_mae: 0.0935
#
# Epoch 16/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0491 - mae: 0.0491 - val_loss: 0.0936 - val_mae: 0.0936
#
# Epoch 17/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0490 - mae: 0.0490 - val_loss: 0.0935 - val_mae: 0.0935
#
# Epoch 18/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0487 - mae: 0.0487 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 19/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0487 - mae: 0.0487 - val_loss: 0.0940 - val_mae: 0.0940
#
# Epoch 20/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0485 - mae: 0.0485 - val_loss: 0.0936 - val_mae: 0.0936
#
# Epoch 21/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0484 - mae: 0.0484 - val_loss: 0.0936 - val_mae: 0.0936
#
# Epoch 22/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0483 - mae: 0.0483 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 23/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0482 - mae: 0.0482 - val_loss: 0.0936 - val_mae: 0.0936
#
# Epoch 24/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0480 - mae: 0.0480 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 25/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0480 - mae: 0.0480 - val_loss: 0.0936 - val_mae: 0.0936
#
# Epoch 26/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0479 - mae: 0.0479 - val_loss: 0.0935 - val_mae: 0.0935
#
# Epoch 27/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0476 - mae: 0.0476 - val_loss: 0.0935 - val_mae: 0.0935
#
# Epoch 28/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0476 - mae: 0.0476 - val_loss: 0.0941 - val_mae: 0.0941
#
# Epoch 29/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0475 - mae: 0.0475 - val_loss: 0.0936 - val_mae: 0.0936
#
# Epoch 30/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0474 - mae: 0.0474 - val_loss: 0.0941 - val_mae: 0.0941
#
# Epoch 1/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0468 - mae: 0.0468 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 2/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0465 - mae: 0.0465 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 3/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0464 - mae: 0.0464 - val_loss: 0.0940 - val_mae: 0.0940
#
# Epoch 4/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0464 - mae: 0.0464 - val_loss: 0.0940 - val_mae: 0.0940
#
# Epoch 5/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0464 - mae: 0.0464 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 6/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0462 - mae: 0.0462 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 7/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0461 - mae: 0.0461 - val_loss: 0.0939 - val_mae: 0.0939
#
# Epoch 8/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0460 - mae: 0.0460 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 9/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0460 - mae: 0.0460 - val_loss: 0.0940 - val_mae: 0.0940
#
# Epoch 10/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0460 - mae: 0.0460 - val_loss: 0.0939 - val_mae: 0.0939
#
# Epoch 11/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0458 - mae: 0.0458 - val_loss: 0.0944 - val_mae: 0.0944
#
# Epoch 12/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0458 - mae: 0.0458 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 13/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0458 - mae: 0.0458 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 14/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0456 - mae: 0.0456 - val_loss: 0.0942 - val_mae: 0.0942
#
# Epoch 15/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0455 - mae: 0.0455 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 16/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0455 - mae: 0.0455 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 17/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0455 - mae: 0.0455 - val_loss: 0.0939 - val_mae: 0.0939
#
# Epoch 18/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0454 - mae: 0.0454 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 19/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0454 - mae: 0.0454 - val_loss: 0.0941 - val_mae: 0.0941
#
# Epoch 20/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0454 - mae: 0.0454 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 21/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0452 - mae: 0.0452 - val_loss: 0.0939 - val_mae: 0.0939
#
# Epoch 22/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0452 - mae: 0.0452 - val_loss: 0.0940 - val_mae: 0.0940
#
# Epoch 23/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0451 - mae: 0.0451 - val_loss: 0.0944 - val_mae: 0.0944
#
# Epoch 24/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0451 - mae: 0.0451 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 25/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0451 - mae: 0.0451 - val_loss: 0.0939 - val_mae: 0.0939
#
# Epoch 26/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0450 - mae: 0.0450 - val_loss: 0.0942 - val_mae: 0.0942
#
# Epoch 27/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0449 - mae: 0.0449 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 28/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0449 - mae: 0.0449 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 29/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0448 - mae: 0.0448 - val_loss: 0.0938 - val_mae: 0.0938
#
# Epoch 30/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0447 - mae: 0.0447 - val_loss: 0.0937 - val_mae: 0.0937
#
# Epoch 1/55
#
# 713/713 [==============================] - 23s 25ms/step - loss: 0.1626 - mae: 0.1626 - val_loss: 0.1567 - val_mae: 0.1567
#
# Epoch 2/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1554 - mae: 0.1554 - val_loss: 0.1493 - val_mae: 0.1493
#
# Epoch 3/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1431 - mae: 0.1431 - val_loss: 0.1360 - val_mae: 0.1360
#
# Epoch 4/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1298 - mae: 0.1298 - val_loss: 0.1223 - val_mae: 0.1223
#
# Epoch 5/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1211 - mae: 0.1211 - val_loss: 0.1186 - val_mae: 0.1186
#
# Epoch 6/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1154 - mae: 0.1154 - val_loss: 0.1117 - val_mae: 0.1117
#
# ...
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0458 - mae: 0.0458 - val_loss: 0.0930 - val_mae: 0.0930
#
# Epoch 30/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0457 - mae: 0.0457 - val_loss: 0.0926 - val_mae: 0.0926
#
# Epoch 1/55
#
# 713/713 [==============================] - 23s 24ms/step - loss: 0.1618 - mae: 0.1618 - val_loss: 0.1584 - val_mae: 0.1584
#
# Epoch 2/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1556 - mae: 0.1556 - val_loss: 0.1508 - val_mae: 0.1508
#
# Epoch 3/55
#
# 713/713 [==============================] - 15s 20ms/step - loss: 0.1464 - mae: 0.1464 - val_loss: 0.1396 - val_mae: 0.1396
#
# Epoch 4/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1373 - mae: 0.1373 - val_loss: 0.1302 - val_mae: 0.1302
#
# Epoch 5/55
#
# 713/713 [==============================] - 14s 20ms/step - loss: 0.1292 - mae: 0.1292 - val_loss: 0.1236 - val_mae: 0.1236
#
# Epoch 6/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1224 - mae: 0.1224 - val_loss: 0.1185 - val_mae: 0.1185
#
# Epoch 7/55
#
# 713/713 [==============================] - 15s 20ms/step - loss: 0.1165 - mae: 0.1165 - val_loss: 0.1180 - val_mae: 0.1180
#
# Epoch 8/55
#
# 713/713 [==============================] - 16s 22ms/step - loss: 0.1119 - mae: 0.1119 - val_loss: 0.1113 - val_mae: 0.1113
#
# Epoch 9/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1084 - mae: 0.1084 - val_loss: 0.1110 - val_mae: 0.1110
#
# Epoch 10/55
#
# 713/713 [==============================] - 15s 22ms/step - loss: 0.1058 - mae: 0.1058 - val_loss: 0.1058 - val_mae: 0.1058
#
# Epoch 11/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.1031 - mae: 0.1031 - val_loss: 0.1069 - val_mae: 0.1069
#
# Epoch 12/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.1007 - mae: 0.1007 - val_loss: 0.1035 - val_mae: 0.1035
#
# Epoch 13/55
#
# 713/713 [==============================] - 15s 22ms/step - loss: 0.0988 - mae: 0.0988 - val_loss: 0.1022 - val_mae: 0.1022
#
# Epoch 14/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0968 - mae: 0.0968 - val_loss: 0.1027 - val_mae: 0.1027
#
# Epoch 15/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0952 - mae: 0.0952 - val_loss: 0.0993 - val_mae: 0.0993
#
# Epoch 16/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0933 - mae: 0.0933 - val_loss: 0.1036 - val_mae: 0.1036
#
# Epoch 17/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0914 - mae: 0.0914 - val_loss: 0.0986 - val_mae: 0.0986
#
# Epoch 18/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0896 - mae: 0.0896 - val_loss: 0.0978 - val_mae: 0.0978
#
# Epoch 19/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0884 - mae: 0.0884 - val_loss: 0.0990 - val_mae: 0.0990
#
# Epoch 20/55
#
# 713/713 [==============================] - 15s 20ms/step - loss: 0.0870 - mae: 0.0870 - val_loss: 0.0977 - val_mae: 0.0977
#
# Epoch 21/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0854 - mae: 0.0854 - val_loss: 0.0976 - val_mae: 0.0976
#
# Epoch 22/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0840 - mae: 0.0840 - val_loss: 0.0983 - val_mae: 0.0983
#
# Epoch 23/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0825 - mae: 0.0825 - val_loss: 0.0978 - val_mae: 0.0978
#
# Epoch 24/55
#
# 713/713 [==============================] - 14s 20ms/step - loss: 0.0816 - mae: 0.0816 - val_loss: 0.0976 - val_mae: 0.0976
#
# Epoch 25/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0805 - mae: 0.0805 - val_loss: 0.0979 - val_mae: 0.0979
#
# Epoch 26/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0790 - mae: 0.0790 - val_loss: 0.0959 - val_mae: 0.0959
#
# Epoch 27/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0775 - mae: 0.0775 - val_loss: 0.0961 - val_mae: 0.0961
#
# Epoch 28/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0769 - mae: 0.0769 - val_loss: 0.0961 - val_mae: 0.0961
#
# Epoch 29/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0756 - mae: 0.0756 - val_loss: 0.0967 - val_mae: 0.0967
#
# Epoch 30/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0747 - mae: 0.0747 - val_loss: 0.0963 - val_mae: 0.0963
#
# Epoch 31/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0739 - mae: 0.0739 - val_loss: 0.0967 - val_mae: 0.0967
#
# Epoch 32/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0726 - mae: 0.0726 - val_loss: 0.0960 - val_mae: 0.0960
#
# Epoch 33/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0720 - mae: 0.0720 - val_loss: 0.0974 - val_mae: 0.0974
#
# Epoch 34/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0709 - mae: 0.0709 - val_loss: 0.0971 - val_mae: 0.0971
#
# Epoch 35/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0702 - mae: 0.0702 - val_loss: 0.0969 - val_mae: 0.0969
#
# Epoch 36/55
#
# 713/713 [==============================] - 15s 20ms/step - loss: 0.0693 - mae: 0.0693 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 37/55
#
# 713/713 [==============================] - 15s 21ms/step - loss: 0.0685 - mae: 0.0685 - val_loss: 0.0954 - val_mae: 0.0954
#
# Epoch 38/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0678 - mae: 0.0678 - val_loss: 0.0979 - val_mae: 0.0979
#
# Epoch 39/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0672 - mae: 0.0672 - val_loss: 0.0970 - val_mae: 0.0970
#
# Epoch 40/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0666 - mae: 0.0666 - val_loss: 0.0974 - val_mae: 0.0974
#
# Epoch 41/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0656 - mae: 0.0656 - val_loss: 0.0965 - val_mae: 0.0965
#
# Epoch 42/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0652 - mae: 0.0652 - val_loss: 0.0964 - val_mae: 0.0964
#
# Epoch 43/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0967 - val_mae: 0.0967
#
# Epoch 44/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0642 - mae: 0.0642 - val_loss: 0.0979 - val_mae: 0.0979
#
# Epoch 45/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0638 - mae: 0.0638 - val_loss: 0.0966 - val_mae: 0.0966
#
# Epoch 46/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0635 - mae: 0.0635 - val_loss: 0.0960 - val_mae: 0.0960
#
# Epoch 47/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0627 - mae: 0.0627 - val_loss: 0.0975 - val_mae: 0.0975
#
# Epoch 48/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0620 - mae: 0.0620 - val_loss: 0.0969 - val_mae: 0.0969
#
# Epoch 49/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0618 - mae: 0.0618 - val_loss: 0.0987 - val_mae: 0.0987
#
# Epoch 50/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0610 - mae: 0.0610 - val_loss: 0.0962 - val_mae: 0.0962
#
# Epoch 51/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0610 - mae: 0.0610 - val_loss: 0.0969 - val_mae: 0.0969
#
# Epoch 52/55
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0608 - mae: 0.0608 - val_loss: 0.0961 - val_mae: 0.0961
#
# Epoch 53/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0598 - mae: 0.0598 - val_loss: 0.0969 - val_mae: 0.0969
#
# Epoch 54/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0596 - mae: 0.0596 - val_loss: 0.0981 - val_mae: 0.0981
#
# Epoch 55/55
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0590 - mae: 0.0590 - val_loss: 0.0979 - val_mae: 0.0979
#
# Epoch 1/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0545 - mae: 0.0545 - val_loss: 0.0960 - val_mae: 0.0960
#
# Epoch 2/30
#
# 713/713 [==============================] - 15s 20ms/step - loss: 0.0532 - mae: 0.0532 - val_loss: 0.0949 - val_mae: 0.0949
#
# Epoch 3/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0525 - mae: 0.0525 - val_loss: 0.0954 - val_mae: 0.0954
#
# Epoch 4/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0521 - mae: 0.0521 - val_loss: 0.0962 - val_mae: 0.0962
#
# Epoch 5/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0517 - mae: 0.0517 - val_loss: 0.0962 - val_mae: 0.0962
#
# Epoch 6/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0514 - mae: 0.0514 - val_loss: 0.0952 - val_mae: 0.0952
#
# Epoch 7/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0511 - mae: 0.0511 - val_loss: 0.0960 - val_mae: 0.0960
#
# Epoch 8/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0509 - mae: 0.0509 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 9/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0506 - mae: 0.0506 - val_loss: 0.0958 - val_mae: 0.0958
#
# Epoch 10/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0504 - mae: 0.0504 - val_loss: 0.0960 - val_mae: 0.0960
#
# Epoch 11/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0501 - mae: 0.0501 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 12/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0500 - mae: 0.0500 - val_loss: 0.0952 - val_mae: 0.0952
#
# Epoch 13/30
#
# 713/713 [==============================] - 15s 22ms/step - loss: 0.0499 - mae: 0.0499 - val_loss: 0.0949 - val_mae: 0.0949
#
# Epoch 14/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0496 - mae: 0.0496 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 15/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0494 - mae: 0.0494 - val_loss: 0.0957 - val_mae: 0.0957
#
# Epoch 16/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0493 - mae: 0.0493 - val_loss: 0.0954 - val_mae: 0.0954
#
# Epoch 17/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0492 - mae: 0.0492 - val_loss: 0.0961 - val_mae: 0.0961
#
# Epoch 18/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0490 - mae: 0.0490 - val_loss: 0.0958 - val_mae: 0.0958
#
# Epoch 19/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0489 - mae: 0.0489 - val_loss: 0.0950 - val_mae: 0.0950
#
# Epoch 20/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0487 - mae: 0.0487 - val_loss: 0.0952 - val_mae: 0.0952
#
# Epoch 21/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0485 - mae: 0.0485 - val_loss: 0.0961 - val_mae: 0.0961
#
# Epoch 22/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0485 - mae: 0.0485 - val_loss: 0.0960 - val_mae: 0.0960
#
# Epoch 23/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0483 - mae: 0.0483 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 24/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0482 - mae: 0.0482 - val_loss: 0.0956 - val_mae: 0.0956
#
# Epoch 25/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0481 - mae: 0.0481 - val_loss: 0.0951 - val_mae: 0.0951
#
# Epoch 26/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0480 - mae: 0.0480 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 27/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0479 - mae: 0.0479 - val_loss: 0.0952 - val_mae: 0.0952
#
# Epoch 28/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0477 - mae: 0.0477 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 29/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0474 - mae: 0.0474 - val_loss: 0.0954 - val_mae: 0.0954
#
# Epoch 30/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0474 - mae: 0.0474 - val_loss: 0.0952 - val_mae: 0.0952
#
# Epoch 1/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0468 - mae: 0.0468 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 2/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0468 - mae: 0.0468 - val_loss: 0.0954 - val_mae: 0.0954
#
# Epoch 3/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0466 - mae: 0.0466 - val_loss: 0.0950 - val_mae: 0.0950
#
# Epoch 4/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0465 - mae: 0.0465 - val_loss: 0.0954 - val_mae: 0.0954
#
# Epoch 5/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0464 - mae: 0.0464 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 6/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0463 - mae: 0.0463 - val_loss: 0.0954 - val_mae: 0.0954
#
# Epoch 7/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0462 - mae: 0.0462 - val_loss: 0.0957 - val_mae: 0.0957
#
# Epoch 8/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0461 - mae: 0.0461 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 9/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0461 - mae: 0.0461 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 10/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0461 - mae: 0.0461 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 11/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0459 - mae: 0.0459 - val_loss: 0.0956 - val_mae: 0.0956
#
# Epoch 12/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0459 - mae: 0.0459 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 13/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0459 - mae: 0.0459 - val_loss: 0.0956 - val_mae: 0.0956
#
# Epoch 14/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0458 - mae: 0.0458 - val_loss: 0.0954 - val_mae: 0.0954
#
# Epoch 15/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0457 - mae: 0.0457 - val_loss: 0.0959 - val_mae: 0.0959
#
# Epoch 16/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0457 - mae: 0.0457 - val_loss: 0.0951 - val_mae: 0.0951
#
# Epoch 17/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0456 - mae: 0.0456 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 18/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0456 - mae: 0.0456 - val_loss: 0.0953 - val_mae: 0.0953
#
# Epoch 19/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0455 - mae: 0.0455 - val_loss: 0.0952 - val_mae: 0.0952
#
# Epoch 20/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0454 - mae: 0.0454 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 21/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0454 - mae: 0.0454 - val_loss: 0.0956 - val_mae: 0.0956
#
# Epoch 22/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0453 - mae: 0.0453 - val_loss: 0.0952 - val_mae: 0.0952
#
# Epoch 23/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0453 - mae: 0.0453 - val_loss: 0.0957 - val_mae: 0.0957
#
# Epoch 24/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0452 - mae: 0.0452 - val_loss: 0.0954 - val_mae: 0.0954
#
# Epoch 25/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0451 - mae: 0.0451 - val_loss: 0.0958 - val_mae: 0.0958
#
# Epoch 26/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0450 - mae: 0.0450 - val_loss: 0.0957 - val_mae: 0.0957
#
# Epoch 27/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0451 - mae: 0.0451 - val_loss: 0.0958 - val_mae: 0.0958
#
# Epoch 28/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0450 - mae: 0.0450 - val_loss: 0.0955 - val_mae: 0.0955
#
# Epoch 29/30
#
# 713/713 [==============================] - 11s 16ms/step - loss: 0.0450 - mae: 0.0450 - val_loss: 0.0956 - val_mae: 0.0956
#
# Epoch 30/30
#
# 713/713 [==============================] - 11s 15ms/step - loss: 0.0449 - mae: 0.0449 - val_loss: 0.0959 - val_mae: 0.0959

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable


saved_model = load_model('best_model_2_0.hp5', custom_objects= {'custom_loss': custom_loss})


# Predictions using x_test. x_test are unknown data that were not included in the training process
predictions = saved_model.predict(x_test)


# Load the best model
for i in range(1,10):
    saved_model = load_model('best_model_2_{}.hp5'.format(i), custom_objects= {'custom_loss': custom_loss})


    # Predictions using x_test. x_test are unknown data that were not included in the training process
    predictions = predictions + saved_model.predict(x_test)

predictions = predictions/10

# plot the results
for i, c in enumerate(predictions):
    sh = np.shape(c)

    # Actual size of the model i.e. 50x22 meters
    xc = np.linspace(0,50,sh[0])
    yc = np.linspace(0,22,sh[1])

    plt.subplot(1,2,1)
    ax = plt.gca()
    c = (c+0.5)*10
    im = ax.imshow(c, extent=[0, 50, -22, 0],vmin = c.min(), vmax = c.max())
    plt.title('ML Inversion')
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
    plt.xlabel('X-axis (m)')
    plt.ylabel('Depth (m)')

    plt.subplot(1,2,2)
    ax = plt.gca()
    im = ax.imshow((y_test[i,:,:]+0.5)*10, extent=[0, 50, -22, 0], vmin = c.min(), vmax = c.max())
    plt.title('Ground_Truth')

    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
    plt.xlabel('X-axis (m)')
    plt.ylabel('Depth (m)')
    plt.tight_layout()

    plt.show()
